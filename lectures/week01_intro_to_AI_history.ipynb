# %% [markdown]
# # Week 1 — AI와 역사, 재현성과 윤리

# %% [markdown]
# 이 노트북은 Colab에서 실행하도록 설계되었습니다. 런타임을 GPU로 바꿀 필요는 없습니다.

# %%
# Colab 환경 준비 (옵션)
import sys, platform
print(platform.python_version())

# %% [markdown]
# ## 학습목표
# - AI의 기본 개념 이해
# - 역사연구에서 데이터의 재현성 개념 학습
# - Colab과 GitHub 연동 실습

# %%
# GitHub에 사본 저장: File → Save a copy in GitHub
# 패키지 기본
import pandas as pd
import numpy as np
df = pd.read_csv('/mnt/data/AI-History-Course-2025/data/sample_historical_texts.csv')
df.head()
